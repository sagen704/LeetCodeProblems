# %% [markdown]
# # Smallest Missing Integer Greater Than Sequential Prefix Sum

# %% [markdown]
# ## Date: Aug 11, 2026

# %% [markdown]
# ## Tags
#
# **Difficulty:** Easy
#
# **Topics:** Hash Map, Array

# %% [markdown]
# ## Description
#
# You are given a 0-indexed array of integers nums.
#
# A prefix nums[0..i] is sequential if, for all 1 <= j <= i, nums[j] = nums[j - 1] + 1. In particular, the prefix consisting only of nums[0] is sequential.
#
# Return the smallest integer x missing from nums such that x is greater than or equal to the sum of the longest sequential prefix.

# %% [markdown]
# ## My First Solution
#
# So the first while loop is to get the prefix sum so it loops while the first numbers are in order. Then I create the target number but summing the first 0-l numbers and then I turn the nums into a set so then I can search in O(1) time. I search from the summed prefix number counting up until it is not in the set.

# %%
class Solution:
    def missingInteger(self, nums: List[int]) -> int:

        nums_set = set(nums)

        l = 1

        while l < len(nums) and nums[l] == nums[l-1] + 1:
            l += 1

        target = sum(nums[0:l])

        while target in nums_set:
            target += 1

        return target

# %% [markdown]
# ## Why First Solution is Not Good Enough
#
# (It is slow)

# %% [markdown]
# ## My Second Solution
#
# (How I made it better)

# %%
# Second Solution

# %% [markdown]
# # Notes & Things Learned
